# %%
import pandas as pd

# %%
abspath = '/Users/spencerbertsch/Desktop/winequality-red.csv'
df = pd.read_csv(abspath, sep=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
[col for col in df.columns]
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
predictors: list = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide',
 'density', 'pH', 'sulphates', 'alcohol']
response: list = ['quality']

# define our features and labels
X = df[predictors]
y = df[response]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=23)

# %%
X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 139             7.8              0.56         0.19             2.0      0.081
# 1469            7.3              0.98         0.05             2.1      0.061
# 432            11.9              0.37         0.69             2.3      0.078
# 1295            6.6              0.63         0.00             4.3      0.093
# 715             7.2              0.49         0.18             2.7      0.069
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 139                  17.0                 108.0  0.99620  3.32       0.54
# 1469                 20.0                  49.0  0.99705  3.31       0.55
# 432                  12.0                  24.0  0.99580  3.00       0.65
# 1295                 51.0                  77.5  0.99558  3.20       0.45
# 715                  13.0                  34.0  0.99670  3.29       0.48
#
#       alcohol
# 139       9.5
# 1469      9.7
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=5, random_state=0).fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train) # Note: x_0 =1 is no need to add, sklearn will take care of it.
# Out:
# LinearRegression()

# %%
pd.DataFrame(lin_reg.coef_).T
# Out:
#            0
# 0   0.012773
# 1  -1.165502
# 2  -0.252890
# 3   0.021531
# 4  -1.605481
# 5   0.003421
# 6  -0.003110
# 7  -7.480351
# 8  -0.455111
# 9   0.846634
# 10  0.278801

# %%
list(lin_reg.intercept_) + list(lin_reg.coef_)
# Out:
# [11.89016296850894,
#  array([ 1.27726671e-02, -1.16550234e+00, -2.52889885e-01,  2.15305926e-02,
#         -1.60548081e+00,  3.42075613e-03, -3.11041026e-03, -7.48035124e+00,
#         -4.55110995e-01,  8.46633536e-01,  2.78801039e-01])]

# %%
Beta = list(lin_reg.coef_[0])

# %%
# sklearn regression module
y_pred = lin_reg.predict(X_test)

#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred, y_test)

# R_square
R_square_sk = lin_reg.score(X_test, y_test)
print('The Mean Square Error(MSE) or J(theta) is: ',mse)
print('R square obtain for scikit learn library is :',R_square_sk)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  0.3621492674185538
# R square obtain for scikit learn library is : 0.4057037662875015
